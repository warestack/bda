# %% [markdown]
# # **PART 1: Data Cleaning**

# %% [markdown]
# **Question 1:** Load the *Movies.csv* file in the Colab and *read* it as a dataframe.

# %%
# Provide your solution here
# Out:
#                                   Film      Genre  ... Worldwide Gross  Year
# 0   You Will Meet a Tall Dark Stranger     Comedy  ...         $26.66   2010
# 1                         Love Happens      Drama  ...         $36.08   2009
# 2                   The Heartbreak Kid     Comedy  ...        $127.77   2007
# 3                         When in Rome     Comedy  ...         $43.04   2010
# 4                              Killers     Action  ...         $93.40   2010
# ..                                 ...        ...  ...             ...   ...
# 71                My Week with Marilyn      Drama  ...          $8.26   2011
# 72                   Midnight in Paris    Romence  ...        $148.66   2011
# 73                             Tangled  Animation  ...        $355.01   2010
# 74                  A Dangerous Method      Drama  ...          $8.97   2011
# 75                              WALL-E  Animation  ...        $521.28   2008
#
# [76 rows x 8 columns]

# %% [markdown]
# > Note that Colab deletes the csv files after some time. Uploaded files will get deleted when the runtime is recycled by Colab. So you might need to upload the file again in the future.

# %% [markdown]
# **Question 2:** Examine the data schema by printing the *types* of data (using the *dtypes*) for each column. Provide the answer for each question.

# %%
# Provide your solution here


# How many columns do we have? ____

# What type is the Genre column? ____
# Out:
# Film                  object
# Genre                 object
# Lead Studio           object
# Audience score %     float64
# Profitability        float64
# Rotten Tomatoes %      int64
# Worldwide Gross       object
# Year                   int64
# dtype: object

# %% [markdown]
# **Question 3:** Continue examinig the dataset, let us focus on the **numerical** data (columns include **Audience score %**, **Profitability** and **Rotten Tomatoes %**). Describe the dataset and answer the following questions.

# %%
# Provide your solution here


# What is the average of Profitability? ____

# What is the average of Audience score %? ____

# What is the max and min scores for Rotten Tomatoes %? ____

# What is the range of the years of our data: from ____ to ____
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         74.000000      76.000000          76.000000    76.000000
# mean          63.378378       4.637009          46.473684  2009.092105
# std           13.707015       8.078562          26.191334     1.358211
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.775796          26.000000  2008.000000
# 50%           63.000000       2.645711          44.000000  2009.000000
# 75%           75.500000       5.163243          63.500000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %% [markdown]
# **Question 4:** Print the last 3 rows of your dataframe.

# %%
# Provide your solution here
# Out:
#                   Film      Genre  ... Worldwide Gross  Year
# 73             Tangled  Animation  ...        $355.01   2010
# 74  A Dangerous Method      Drama  ...          $8.97   2011
# 75              WALL-E  Animation  ...        $521.28   2008
#
# [3 rows x 8 columns]

# %% [markdown]
# **Question 5:** Use the *isnull().sum()* method to examine the dataset for empty rows.

# %%
# Provide your solution here
# Out:
# Film                 0
# Genre                0
# Lead Studio          1
# Audience score %     2
# Profitability        0
# Rotten Tomatoes %    0
# Worldwide Gross      0
# Year                 0
# dtype: int64

# %% [markdown]
# **Question 6:** Query the dataset to find and print the rows that have empty values (NaN) in the *Lead Studio* column.

# %%
# Provide your solution here
# Out:
#       Film      Genre Lead Studio  ...  Rotten Tomatoes %  Worldwide Gross  Year
# 75  WALL-E  Animation         NaN  ...                 96         $521.28   2008
#
# [1 rows x 8 columns]

# %% [markdown]
# **Question 7:** Provide a script to **count** how many **empty** cells there are in the dataframe.

# %%
# Provide your solution here
# Out:
# 3

# %% [markdown]
# **Question 8:** Provide a script to **replace** all the empty cells of the *Lead Studio* column with the keyword *missing*. Print the last 3 rows to examine the dataset. Revise the slides and make sure you set *inplace = True* to apply the change.

# %%
# Provide your solution here
# Out:
#                   Film      Genre  ... Worldwide Gross  Year
# 73             Tangled  Animation  ...        $355.01   2010
# 74  A Dangerous Method      Drama  ...          $8.97   2011
# 75              WALL-E  Animation  ...        $521.28   2008
#
# [3 rows x 8 columns]

# %% [markdown]
# **Question 9:** *Replace* the *missing* value of the column *Lead Studio* and row 75 to **Disney**. Then use the **loc** to print the 75th row.

# %%
# Provide your solution here
# Out:
#       Film      Genre Lead Studio  ...  Rotten Tomatoes %  Worldwide Gross  Year
# 75  WALL-E  Animation      Disney  ...                 96         $521.28   2008
#
# [1 rows x 8 columns]

# %% [markdown]
# 🚨
# We can extract useful statistics such as the oldest employee is 53, the youngest is 23, the average age is 34.73. Similar statistics are also generated automatically for the rest of the integer-based columns (height and weight).

# %% [markdown]
# **Question 10:** We can use the **loc** method to query for all the **Disney** movies (using the appropriate column).

# %%
# Provide your solution here
# Out:
#                                   Film      Genre  ... Worldwide Gross  Year
# 3                         When in Rome     Comedy  ...         $43.04   2010
# 20                   Gnomeo and Juliet  Animation  ...        $193.97   2011
# 21                   Gnomeo and Juliet  Animation  ...        $193.97   2011
# 55                        The Proposal     Comedy  ...        $314.70   2009
# 58  High School Musical 3: Senior Year     Comedy  ...        $252.04   2008
# 62                           Enchanted     Comedy  ...        $340.49   2007
# 73                             Tangled  Animation  ...        $355.01   2010
# 75                              WALL-E  Animation  ...        $521.28   2008
#
# [8 rows x 8 columns]

# %% [markdown]
# **Question 10:** Query the dataset to **count** the number of movies per **Genre**. Print the results. You can use the *groupby* method as seen in previous class and the *filter* method to filter by *Film* column.

# %%
# Provide your solution here
# Out:
#            Film
# Genre
# Action        1
# Animation     4
# Comdy         1
# Comedy       41
# Drama        13
# Fantasy       1
# Romance      12
# Romence       1
# comedy        1
# romance       1

# %% [markdown]
# **Question 11:** Query the dataset to **show** the empty record of the *Audience score %* column. Then, keep a note of the row indexes.

# %%
# Provide your solution here


# Empty Audience score % in rows: _______
# Out:
#                    Film    Genre  ... Worldwide Gross  Year
# 37     It's Complicated   Comedy  ...        $224.60   2009
# 70  Across the Universe  romance  ...         $29.37   2007
#
# [2 rows x 8 columns]

# %% [markdown]
# **Question 12:** Provide a script to fill the empty cells in the *Audience score %* with the mean of the *Audience score %*. Then print all the rows from row with index 35 to 71 (inclusive). Run and examine the following code.
#
# Did you identify any problems?

# %% [markdown]
# 🚨
# > We make a copy of the results to a test dataframe variable called *testdf1*. We do not want to make results permanent yet using the *inplace*= True! We are currently exploring possible ways to move forward.

# %%
# Examine the following code


# The problem: ________
# Out:
# 35    62.000000
# 36    62.000000
# 37    63.378378
# 38    64.000000
# 39    64.000000
# 40    65.000000
# 41    66.000000
# 42    66.000000
# 43    67.000000
# 44    67.000000
# 45    68.000000
# 46    68.000000
# 47    68.000000
# 48    70.000000
# 49    70.000000
# 50    70.000000
# 51    71.000000
# 52    72.000000
# 53    72.000000
# 54    74.000000
# 55    74.000000
# 56    76.000000
# 57    76.000000
# 58    76.000000
# 59    77.000000
# 60    77.000000
# 61    78.000000
# 62    80.000000
# 63    80.000000
# 64    81.000000
# 65    81.000000
# 66    81.000000
# 67    82.000000
# 68    82.000000
# 69    83.000000
# 70    63.378378
# Name: Audience score %, dtype: float64

# %% [markdown]
# **Question 13:** Use the *interpolate* method, as seen in class to fill the missing values of the *Audience score %* column. Print the affected rows and examine the results. As before create a new *testdf2* variable to store the results for further analysis.

# %%
# Provide your solution here
# Out:
# 35    62.0
# 70    83.5
# Name: Audience score %, dtype: float64

# %% [markdown]
# 🚨
# > To make results permanent in our dataframe we need to run again the same command but including the option *inplace=True*).

# %% [markdown]
# **Question 14:** Revise the slides and run the command to **fill** all the missing cells of the *Audience score %* column with the interpolated values. Make the results permanent to the dataframe *df*.
#
# Print the affected values once more.

# %%
# Provide your solution here
# Out:
#                    Film    Genre  ... Worldwide Gross  Year
# 35   Life as We Know It   Comedy  ...         $96.16   2010
# 70  Across the Universe  romance  ...         $29.37   2007
#
# [2 rows x 8 columns]

# %% [markdown]
# > Looks better, by examining the dataset we were able to clean it and fill the missing values.

# %% [markdown]
# # **PART 2: Visualisations**

# %% [markdown]
# **Question 15:** Study and run the following code to import the *matplotlib* and *seaborn* Python libraries.

# %%
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns

print("Matplotlib and Seaborn are imported")
# Out:
# Matplotlib and Seaborn are imported

# %% [markdown]
# **Question 16:** Generate a plot using the **lmplot** method to demonstrate the replationship between the columns: *Audience score %* and *Rotten Tomatoes %*.
#
# What can you see in this diagram?

# %%
# Study and run the following code

sns.lmplot(x='Audience score %', y='Rotten Tomatoes %', data=df, size=10, scatter_kws={"s": 100})

# Note size refers to the size of the plot and scatter_kws={"s": 100} refers to the size of the points


# What is this diagram about? 
# ___________
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Question 17:** Generate a plot using the *lmplot* method to demonstrate the replationship between the columns: *Audience score %* and *Rotten Tomatoes %*.
# This time, do not use the regression line and set the hue parameter to *Genre*.
#
# What can you see in this diagram?

# %%
# Provide your solution here


# What is the dominant movie genre? 
# _________
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Question 18:** Examine the above diagram and provide a short description of your findings.

# %%
# Provide your solution here:

# Did you find any interesting cases in your dataset?
# We can draw some conclusions by studying the plot about the relationship
#  of audience and rotten tomatoes scores!

# The following images demonstrate some findings.

# Did you find any issues?
# There are records in the Genre column that refer to the same category
#  For example: ________________

# %% [markdown]
# ![Capture3.PNG](data:image/png;base64,...)![Capture2.PNG](data:image/png;base64,...)![Capture1.PNG](data:image/png;base64,...)

# %% [markdown]
# **Question 19:** Plot a diagram to show the distribution of the *Audience score %* data. Use the *distplot* method as seen in class.

# %%
# Provide your solution here
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Question 20:** Plot a *boxplot* diagram. Study and run the following code. Note that the notches represent the confidence interval around the median.

# %%
# Study and run the following code

# We need to drop the profitability and Year columns to show data for Audience score 
# and Rotten Tomatoes %.
stats_df = df.drop(['Profitability','Year'], axis=1)

# The boxplot shows the confidence intervals
sns.boxplot(data=stats_df)

# %% [markdown]
# ![Light Bulb On.webp](data:image/webp;base64,...) A Confidence Interval is a range of values we are fairly sure our true value lies in. Study the following example. [
# Source: https://www.mathsisfun.com/data/confidence-interval.html]
#
# ![Capture4.PNG](data:image/png;base64,...)
